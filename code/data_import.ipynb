# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
def get_trace(df, x_col, y_col):
    mask = df[x_col].notna()
    x = df.loc[mask, x_col].values
    y    = df.loc[mask, y_col].values
    return x, y

# %%
# Enter your directory as needed
directory = r"C:\Users\nbaol\iCloudDrive\gridium_paper\figure_data"

# %% [markdown]
# # Figure 1, panel c

# %%
fname = r"\fig1c.csv"
df = pd.read_csv(directory+fname)
phase, phase_wf_0 = get_trace(df, "phase", "phase_wf_0")
_, phase_wf_1 = get_trace(df, "phase", "phase_wf_1")
charge, charge_wf_0 = get_trace(df, "charge", "charge_wf_0")
_, charge_wf_1 = get_trace(df, "charge", "charge_wf_1")

# %% [markdown]
# # Figure 3

# %% [markdown]
# ## Panel a

# %%
fname = r"\fig3a.csv"
df = pd.read_csv(directory+fname)
current_diff = np.sort(df["current_diff"].unique())
current_common = np.sort(df["current_common"].unique())
signal = df.pivot_table(
    index="current_common",   # rows (y-axis)
    columns="current_diff",   # columns (x-axis)
    values="signal"
)

# %% [markdown]
# ## Panel b

# %%
fname = r"\fig3b.csv"
df = pd.read_csv(directory+fname)
flux_data = np.sort(df["flux_data"].unique())
f01_data = np.array(df["f01_data"])
f03_data = np.array(df["f03_data"])
flux_numeric = np.sort(df["flux_numeric"].unique())
f01_numeric = np.array(df["f01_numeric"])
f03_numeric = np.array(df["f03_numeric"])

# %% [markdown]
# ## Panel c

# %%
fname = r"\fig3c.csv"
df = pd.read_csv(directory+fname)

flux_01_data, f01_data = get_trace(df, "flux_01_data", "f01_data")
flux_02_data, f02_data = get_trace(df, "flux_02_data", "f02_data")
flux_05_data, f05_data = get_trace(df, "flux_05_data", "f05_data")
flux_12_data, f12_data = get_trace(df, "flux_12_data", "f12_data")
flux_13_data, f13_data = get_trace(df, "flux_13_data", "f13_data")
flux_15_data, f15_data = get_trace(df, "flux_15_data", "f15_data")
flux_17_data, f17_data = get_trace(df, "flux_17_data", "f17_data")

flux_numeric = df["flux_numeric"].dropna().values
f01_numeric  = df["f01_numeric"].dropna().values
f02_numeric  = df["f02_numeric"].dropna().values
f05_numeric  = df["f05_numeric"].dropna().values
f12_numeric  = df["f12_numeric"].dropna().values
f13_numeric  = df["f13_numeric"].dropna().values
f15_numeric  = df["f15_numeric"].dropna().values
f17_numeric  = df["f17_numeric"].dropna().values

# %% [markdown]
# ## Panel d

# %%
fname = r"\fig3d.csv"
df = pd.read_csv(directory+fname)
phi_ext = np.sort(df["phi_ext"].unique())
theta_ext = np.sort(df["theta_ext"].unique())
e0 = df.pivot_table(
    index="phi_ext",   # rows (y-axis)
    columns="theta_ext",   # columns (x-axis)
    values="e0"
)
e1 = df.pivot_table(
    index="phi_ext",   # rows (y-axis)
    columns="theta_ext",   # columns (x-axis)
    values="e1"
)

# %% [markdown]
# ## Panel e

# %%
fname = r"\fig3e.csv"
df = pd.read_csv(directory+fname)
phase, phase_wf_0 = get_trace(df, "phase", "phase_wf_0")
_, phase_wf_1 = get_trace(df, "phase", "phase_wf_1")
charge, charge_wf_0 = get_trace(df, "charge", "charge_wf_0")
_, charge_wf_1 = get_trace(df, "charge", "charge_wf_1")

# %% [markdown]
# ## Panel f

# %%
fname = r"\fig3f.csv"
df = pd.read_csv(directory+fname)

flux_data, f12_data = get_trace(df, "flux_data", "f12_data")
_, f03_data = get_trace(df, "flux_data", "f03_data")
_, f18_data = get_trace(df, "flux_data", "f18_data")
_, f09_data = get_trace(df, "flux_data", "f09_data")

flux_numeric = df["flux_numeric"].dropna().values
f01_numeric  = df["f01_numeric"].dropna().values
f03_numeric  = df["f03_numeric"].dropna().values
f12_numeric  = df["f12_numeric"].dropna().values
f09_numeric  = df["f09_numeric"].dropna().values
f18_numeric  = df["f18_numeric"].dropna().values

# %% [markdown]
# ## Panel g

# %%
fname = r"\fig3g.csv"
df = pd.read_csv(directory+fname)
phi_ext = np.sort(df["phi_ext"].unique())
theta_ext = np.sort(df["theta_ext"].unique())
e0 = df.pivot_table(
    index="phi_ext",   # rows (y-axis)
    columns="theta_ext",   # columns (x-axis)
    values="e0"
)
e1 = df.pivot_table(
    index="phi_ext",   # rows (y-axis)
    columns="theta_ext",   # columns (x-axis)
    values="e1"
)

# %% [markdown]
# ## Panel h

# %%
fname = r"\fig3h.csv"
df = pd.read_csv(directory+fname)
phase, phase_wf_0 = get_trace(df, "phase", "phase_wf_0")
_, phase_wf_1 = get_trace(df, "phase", "phase_wf_1")
charge, charge_wf_0 = get_trace(df, "charge", "charge_wf_0")
_, charge_wf_1 = get_trace(df, "charge", "charge_wf_1")

# %%
plt.plot(charge,np.real(charge_wf_1))

# %% [markdown]
# # Figure 4

# %% [markdown]
# ## Panel a

# %%
fname = r"\fig4a.csv"
df = pd.read_csv(directory+fname)
time = np.sort(df["time"].unique())
freq = np.sort(df["freq"].unique())
pop = df.pivot_table(
    index="freq",   # rows (y-axis)
    columns="time",   # columns (x-axis)
    values="p"
)

# %% [markdown]
# ## Panel c

# %%
fname = r"\fig4c.csv"
df = pd.read_csv(directory+fname)
time_op, prob_op = get_trace(df, "time_op", "prob_op")
time_pro, prob_pro = get_trace(df, "time_pro", "prob_pro")

# %% [markdown]
# ## Panel d

# %%
fname = r"\fig4d.csv"
df = pd.read_csv(directory+fname)
time_op, prob_op = get_trace(df, "time_op", "prob_op")
time_pro, prob_pro = get_trace(df, "time_pro", "prob_pro")

# %% [markdown]
# # Extended Data Figure 1

# %%
fname = r"\extended_1.csv"
df = pd.read_csv(directory+fname)
minutes = np.sort(df["minutes"].unique())
frequency = np.sort(df["frequency"].unique())
signal = df.pivot_table(
    index="frequency",   # rows (y-axis)
    columns="minutes",   # columns (x-axis)
    values="signal"
)

# %% [markdown]
# # Extended Data Figure 2

# %% [markdown]
# ## Panel a

# %%
fname = r"\extended_2a.csv"
df = pd.read_csv(directory+fname)

flux_01_data, f01_data = get_trace(df, "flux_01_data", "f01_data")
flux_02_data, f02_data = get_trace(df, "flux_02_data", "f02_data")
flux_03_data, f03_data = get_trace(df, "flux_03_data", "f03_data")
flux_04_data, f04_data = get_trace(df, "flux_04_data", "f04_data")

flux_numeric = df["flux_numeric"].dropna().values
f01_numeric  = df["f01_numeric"].dropna().values
f02_numeric  = df["f02_numeric"].dropna().values
f03_numeric  = df["f03_numeric"].dropna().values
f04_numeric  = df["f04_numeric"].dropna().values

# %% [markdown]
# ## Panel b

# %%
fname = r"\extended_2b.csv"
df = pd.read_csv(directory+fname)

flux_12_data, f12_data = get_trace(df, "flux_12_data", "f12_data")
flux_03_data, f03_data = get_trace(df, "flux_03_data", "f03_data")
flux_16_data, f16_data = get_trace(df, "flux_16_data", "f16_data")
flux_07_data, f07_data = get_trace(df, "flux_07_data", "f07_data")

flux_numeric = df["flux_numeric"].dropna().values
f01_numeric  = df["f01_numeric"].dropna().values
f12_numeric  = df["f12_numeric"].dropna().values
f03_numeric  = df["f03_numeric"].dropna().values
f16_numeric  = df["f16_numeric"].dropna().values
f07_numeric  = df["f07_numeric"].dropna().values

# %% [markdown]
# ## Panel c

# %%
fname = r"\extended_2c.csv"
df = pd.read_csv(directory+fname)
phase, phase_wf_0 = get_trace(df, "phase", "phase_wf_0")
_, phase_wf_1 = get_trace(df, "phase", "phase_wf_1")
charge, charge_wf_0 = get_trace(df, "charge", "charge_wf_0")
_, charge_wf_1 = get_trace(df, "charge", "charge_wf_1")

# %% [markdown]
# # Extended Data Figure 3

# %%
fname = r"\extended_3.csv"
df = pd.read_csv(directory+fname)
time_1, freq_1 = get_trace(df, "time_1", "freq_1")
time_2, freq_2 = get_trace(df, "time_2", "freq_2")
time_3, freq_3 = get_trace(df, "time_3", "freq_3")

# %% [markdown]
# # Supplementary Figure S3

# %% [markdown]
# ## Panel d

# %%
fname = r"\figS3d.csv"
df = pd.read_csv(directory+fname)
current = np.sort(df["current"].unique())
freq = np.sort(df["freq"].unique())
signal_grid = df.pivot_table(
    index="freq",   # rows (y-axis)
    columns="current",   # columns (x-axis)
    values="signal"
)
signal = signal_grid.loc[freq, current].values

# %% [markdown]
# ## Panel e

# %%
fname = r"\figS3e.csv"
df = pd.read_csv(directory+fname)
current = np.sort(df["current"].unique())
freq = np.sort(df["freq"].unique())
signal_grid = df.pivot_table(
    index="freq",   # rows (y-axis)
    columns="current",   # columns (x-axis)
    values="signal"
)
signal = signal_grid.loc[freq, current].values

# %% [markdown]
# ## Panel f

# %%
fname = r"\figS3f.csv"
df = pd.read_csv(directory+fname)
t1x, t1y = get_trace(df, "t1_time", "t1_pop")
t2x, t2y = get_trace(df, "echo_time", "echo_pop")

# %% [markdown]
# # Supplementary Figure S12

# %%
fname = r"\figS12.csv"
df = pd.read_csv(directory+fname)
t1x, t1y = get_trace(df, "t1_time", "t1_pop")
t2x, t2y = get_trace(df, "echo_time", "echo_pop")
